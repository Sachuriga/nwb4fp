# %%
import pandas as pd
import numpy as np

# %%
path=r'S:\Sachuriga/Ephys_Recording/CR_CA1/65588/65588_2024-03-04_15-44-37_A_phy_k_manual/cluster_info.tsv'
cluster_info = pd.read_csv(path, index_col=0, sep='\t')

# %%
cluster_info
